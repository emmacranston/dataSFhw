# %%
import pandas as pd

# %%
# import column dict for colname transform
coldict_file = "ASR_column_dict.csv"
col_df = pd.read_csv(coldict_file)

# %%
# import ASR data
asr_2017_file = "ASR_2017.csv"
asr_2017 = pd.read_csv(asr_2017_file)
asr_2017.rename(columns = dict(
    zip(col_df['Source Field Name']
        , col_df['Destination Field Name']
       )
    )
               ,inplace=True)
asr_2017.head()
# Out:
# /var/folders/54/fvj8xtl92fl25v_rfc4twzgw0000gn/T/ipykernel_88308/1179045898.py:3: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   asr_2017 = pd.read_csv(asr_2017_file)
#                       Property Location Assessor Neighborhood Code  \
# 0  0000 0000                       0000                        08H
# 1  0000 0000                       0000                        08H
# 2  0000 0000                       0000                        08H
# 3  0000 0286 JEFFERSON           ST0000                        08H
# 4  0000 0000                       0000                        08H
#
#   Block and Lot  Volume Number Property Class Code  Year Property Built  \
# 0      0001 001              1                   G                 1900
# 1      0002 001              1                   G                 1900
# 2      0004 002              1                 VCI                    0
# ...
